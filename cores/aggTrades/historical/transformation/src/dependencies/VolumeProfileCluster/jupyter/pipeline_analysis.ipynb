# %%
from datetime import datetime, timedelta
from pyspark.sql import SparkSession 
from pyspark.sql.functions import col, when, to_json, struct, lit, udf, collect_list, round as round_, max as max_, min as min_, sum as sum_, first, last
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, LongType, IntegerType, MapType
from pyspark.sql import functions as F
import boto3
import sys
from pandas import Timestamp
from pandas import DataFrame
import time
import io
import calendar
from operator import itemgetter
import freqtrade.vendor.qtpylib.indicators as qtpylib
import numpy as np  # noqa
import pandas as pd  # noqa
import pandas_ta as pta
import talib.abstract as ta
from dateutil.relativedelta import relativedelta
from freqtrade.strategy import IStrategy
from technical.indicators import *
from pandas import Timestamp
import requests
from io import BytesIO
from urllib.request import urlopen
from zipfile import ZipFile
import s3fs
import dotenv
from dotenv import load_dotenv
import os
import sys
import os

# Add the directory containing spark_config.py to the Python path
module_path = '/root/Cicada-binance/cores/aggTrades/historical/transformation/src/VolumeProfileCluster'
if module_path not in sys.path:
    sys.path.append(module_path)

# Now you can import the spark_config module
import spark_config

# %%
load_dotenv()

ACCESS_KEY = os.getenv("AWS_ACCESS_KEY_ID")
SECRET_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")
REGION_NAME = os.getenv("AWS_REGION_NAME")
BUCKET_NAME = os.getenv("AWS_BUCKET_NAME")

# %%
import sys
import os

# Set the SPARK_HOME and PATH environment variables
os.environ['SPARK_HOME'] = '/opt/spark'
os.environ['PATH'] += os.pathsep + os.path.join(os.environ['SPARK_HOME'], 'bin')

# Add the directory containing spark_config.py to the Python path
module_path = '/root/Cicada-binance/cores/aggTrades/historical/transformation/src/VolumeProfileCluster'
if module_path not in sys.path:
    sys.path.append(module_path)

# Import the spark_config module
import spark_config

# Get the Spark session
spark_conf = spark_config.get_spark_session()

# %%
# Use boto3 and s3fs for additional S3 interaction
s3_resource = boto3.resource(
    's3',
    region_name=os.getenv("AWS_REGION_NAME"),
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY")
)

s3 = s3fs.S3FileSystem(anon=False, key=os.getenv("AWS_ACCESS_KEY_ID"), secret=os.getenv("AWS_SECRET_ACCESS_KEY"))

# Read data from S3
s3_path = 'xtrus31/cicada-data/HistoricalTradeAggregator/binance_futures/BTCUSDT/2020/01.parquet'
renko = spark_conf.read.parquet(f"s3a://{s3_path}")

new_column_names = [
    "agg_trade_id",
    "price",
    "quantity",
    "first_trade_id",
    "last_trade_id",
    "time",
    "is_buyer_maker",
]
for old_name, new_name in zip(renko.columns, new_column_names):
    renko = renko.withColumnRenamed(old_name, new_name)
# Out:
# 24/06/11 13:53:11 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 24/06/11 13:53:12 WARN BasicProfileConfigLoader: Your profile name includes a 'profile ' prefix. This is considered part of the profile name in the Java SDK, so you will need to include this prefix in your profile name when you reference this profile from your Java code.

# %%
renko.show()
# Out:
# +------------+-------+--------+--------------+-------------+-------------+--------------+
# |agg_trade_id|  price|quantity|first_trade_id|last_trade_id|         time|is_buyer_maker|
# +------------+-------+--------+--------------+-------------+-------------+--------------+
# |    18374167|7189.43|    0.03|      25247504|     25247504|1577836801481|          true|
# |    18374168|7189.42|    1.47|      25247505|     25247505|1577836801481|          true|
# |    18374169|7189.42|   4.222|      25247506|     25247506|1577836801708|          true|
# |    18374170| 7189.0|   0.778|      25247507|     25247507|1577836806290|         false|
# |    18374171| 7189.5|   0.683|      25247508|     25247508|1577836806290|         false|
# |    18374172|7189.99|   0.042|      25247509|     25247509|1577836806291|         false|
# |    18374173|7190.22|     0.3|      25247510|     25247510|1577836806291|         false|
# |    18374174|7190.23|     0.3|      25247511|     25247511|1577836806291|         false|
# |    18374175| 7190.5|   0.078|      25247512|     25247512|1577836806291|         false|
# |    18374176|7190.52|   0.845|      25247513|     25247514|1577836806291|         false|
# |    18374177|7190.05|   5.789|      25247515|     25247515|1577836807161|          true|
# |    18374178|7189.56|   0.043|      25247516|     25247516|1577836807161|          true|
# |    18374179|7188.97|   0.168|      25247517|     25247517|1577836807161|          true|
# |    18374180|7189.93|   0.198|      25247518|     25247518|1577836808274|         false|
# |    18374181|7190.47|   3.529|      25247519|     25247520|1577836809277|          true|
# |    18374182|7190.47|   2.219|      25247521|     25247521|1577836809384|          true|
# |    18374183|7190.11|   3.376|      25247522|     25247523|1577836809630|          true|
# |    18374184|7189.74|   3.602|      25247524|     25247525|1577836809848|          true|
# |    18374185|7189.46|   5.891|      25247526|     25247532|1577836810098|          true|
# |    18374186|7189.16|   0.174|      25247533|     25247533|1577836810197|          true|
# +------------+-------+--------+--------------+-------------+-------------+--------------+
# only showing top 20 rows

# %%
def round_down_to_interval(df, timeframe):
    return df.withColumn(
        "time_rounded",
        (F.col("time") / 1000).cast("timestamp").cast("long")
        - (F.col("time") / 1000).cast("long") % timeframe,
    ).withColumn(
        "time_rounded", F.from_unixtime(F.col("time_rounded")).cast("timestamp")
    )
    
def calc_df(df, aggregate_trades, chart_type, timeframe):
    intervals = {
        "1m": 60,
        "5m": 300,
        "15m": 900,
        "30m": 1800,
        "1h": 3600,
        "4h": 14400,
        "12h": 60 * 60 * 12,
        "1d": 86400,
        "1w": 604800,
    }

    if timeframe not in intervals:
        raise ValueError("Unsupported timeframe provided.")

    interval_seconds = intervals[timeframe]
    df = round_down_to_interval(df, interval_seconds)

    # Define foot_bid and foot_ask columns
    foot_bid = when(
        col("is_buyer_maker") == "true",
        to_json(
            struct(
                col("price").alias("price_level"),
                col("quantity").alias("bid_qty"),
                lit(1).alias("bid_trades"),
                when(lit(aggregate_trades), lit(1)).otherwise(lit(None)).alias("bid_trades_aggr"),
            )
        ),
    )

    foot_ask = when(
        col("is_buyer_maker") == "false",
        to_json(
            struct(
                col("price").alias("price_level"),
                col("quantity").alias("ask_qty"),
                lit(1).alias("ask_trades"),
                when(lit(aggregate_trades), lit(1)).otherwise(lit(None)).alias("ask_trades_aggr"),
            )
        ),
    )

    df = df.withColumn("foot_bid", foot_bid).withColumn("foot_ask", foot_ask)

    # Aggregate to calculate OHLCV and footprint data
    df_agg = (
        df.groupBy(F.window("time_rounded", f"{interval_seconds} seconds"))
        .agg(
            F.first("price").alias("open"),
            F.last("price").alias("close"),
            F.max("price").alias("high"),
            F.min("price").alias("low"),
            F.sum("quantity").alias("qty"),
            F.collect_list("foot_bid").alias("foot_bid"),
            F.collect_list("foot_ask").alias("foot_ask"),
        )
        .select(
            col("window.start").alias("time_rounded"),
            "open",
            "close",
            "high",
            "low",
            "qty",
            "foot_bid",
            "foot_ask",
        )
        .orderBy("time_rounded")
    )

    return df_agg

# %%
chart_type = "candlestick"
aggregate_trades = True

start_year = "2024"
start_month = "04"
end_year = "2024"
end_month = "05"
timeframe = "15m"
renko_df = calc_df(renko, aggregate_trades, chart_type, timeframe)

# %%
renko_df.show()
# Out:
# +-------------------+-------+-------+-------+-------+------------------+--------------------+--------------------+
# |       time_rounded|   open|  close|   high|    low|               qty|            foot_bid|            foot_ask|
# +-------------------+-------+-------+-------+-------+------------------+--------------------+--------------------+
# |2020-01-01 01:00:00|7189.43|7176.26|7190.52|7172.94|1037.3369999999989|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 01:15:00|7176.22|7172.36|7179.41|7170.69| 707.8329999999991|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 01:30:00|7172.79|7174.83|7179.45|7170.61| 325.2459999999999|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 01:45:00|7174.51|7171.55|7179.36|7170.15| 378.6329999999997|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 02:00:00|7171.43| 7186.6|7188.77| 7171.1| 555.3889999999992|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 02:15:00| 7186.6| 7205.9| 7210.0|7184.16|1332.0769999999925|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 02:30:00|7205.89|7206.63| 7225.0|7201.04|1494.2009999999916|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 02:45:00|7206.62|7210.24|7211.42| 7200.0|483.37100000000027|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 03:00:00|7210.38| 7207.3|7217.76|7206.46| 530.6969999999994|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 03:15:00|7207.33| 7221.5|7232.99|7207.33|1007.3589999999958|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 03:30:00|7221.59|7231.11|7231.11|7221.59| 768.5420000000001|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 03:45:00| 7231.1|7237.99| 7239.3| 7228.0| 921.7669999999976|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 04:00:00|7237.41|7222.55|7239.74|7218.29| 815.6149999999984|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 04:15:00|7222.56|7233.19|7233.61|7222.56|424.10499999999905|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 04:30:00|7233.08|7215.37|7238.46|7215.05| 722.1950000000004|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 04:45:00|7215.37|7221.65|7226.24| 7215.0| 551.3919999999994|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 05:00:00| 7221.8| 7215.3|7225.41| 7213.0|302.66799999999995|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 05:15:00| 7215.3|7216.74| 7218.1|7211.22| 401.1239999999998|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 05:30:00|7216.74| 7217.0|7225.07|7216.74|239.41999999999985|[{"price_level":7...|[{"price_level":7...|
# |2020-01-01 05:45:00| 7217.0|7213.86|7223.77|7213.73|233.45400000000015|[{"price_level":7...|[{"price_level":7...|
# +-------------------+-------+-------+-------+-------+------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession, functions as F
from pyspark.sql.types import StructType, StructField, DoubleType, IntegerType, MapType, StringType
from pyspark.sql.functions import udf, collect_list
import logging

# Initialize logger
logger = logging.getLogger("BidAskDataProcessing")
logging.basicConfig(level=logging.INFO)

# Define the schema for bid and ask data
json_schema_bid = StructType([
    StructField("price_level", DoubleType(), True),
    StructField("bid_qty", DoubleType(), True),
    StructField("bid_trades", IntegerType(), True),
    StructField("bid_trades_aggr", IntegerType(), True)
])

json_schema_ask = StructType([
    StructField("price_level", DoubleType(), True),
    StructField("ask_qty", DoubleType(), True),
    StructField("ask_trades", IntegerType(), True),
    StructField("ask_trades_aggr", IntegerType(), True)
])

def process_foot_data(renko_df, column_name, json_schema, prefix):
    # Convert the array to a single JSON string
    df_with_foot = renko_df.withColumn(f"{column_name}_str", F.concat_ws("", F.col(column_name)))
    
    df_with_foot = df_with_foot.withColumn(f"{column_name}_str", F.regexp_replace(f"{column_name}_str", r'\}\s*\{', '},{'))
    
    # Convert the concatenated string to an array of JSON strings
    df_with_foot = df_with_foot.withColumn(f"{column_name}_json_array", F.split(f"{column_name}_str", r',\{'))
    df_with_foot = df_with_foot.withColumn(f"{column_name}_json_array", F.expr(f"TRANSFORM({column_name}_json_array, x -> concat('{{', x))"))
    
    df_with_foot = df_with_foot.withColumn(f"{column_name}_json", F.explode(f"{column_name}_json_array"))
    
    # Replace any occurrences of "{{" with "{" and "}}" with "}"
    df_with_foot = df_with_foot.withColumn(f"{column_name}_json", F.regexp_replace(F.col(f"{column_name}_json"), r'\{\{', '{'))
    df_with_foot = df_with_foot.withColumn(f"{column_name}_json", F.regexp_replace(F.col(f"{column_name}_json"), r'\}\}', '}'))
    
    # Parse JSON and select the necessary fields
    df = df_with_foot.select(
        F.col("time_rounded"),
        F.from_json(F.col(f"{column_name}_json"), json_schema).alias("data")
    ).select(
        "time_rounded",
        F.round(F.col("data.price_level")).alias("price_level"),
        F.col(f"data.{column_name.split('_')[1]}_qty").alias("qty"),
        F.col(f"data.{column_name.split('_')[1]}_trades").alias("trades"),
    ).filter(
        F.col("price_level").isNotNull() &
        F.col("qty").isNotNull() &
        F.col("trades").isNotNull() 
    )
    
    # Aggregate data
    df_agg = df.groupBy("time_rounded", "price_level").agg(
        F.sum("qty").alias(f"total_{prefix}_qty"),
        F.sum("trades").alias(f"total_{prefix}_trades"),
    )
    
    # Sort the aggregated DataFrame by time_rounded and price_level
    df_agg_sorted = df_agg.orderBy("time_rounded", "price_level")
    
    # Additional aggregation step
    df_total_qty = df_agg_sorted.groupBy("time_rounded").agg(
        F.sum(f"total_{prefix}_qty").alias(f"sum_{prefix}_total_qty")
    )

    return df_agg_sorted, df_total_qty

# %%
# Process foot_bid and foot_ask columns
df_bid_agg_sorted, df_bid_total_qty = process_foot_data(renko_df, "foot_bid", json_schema_bid, "bid")
df_bid_agg_sorted.show(20)
# Out:
# [Stage 31:>                                                         (0 + 2) / 2]
# +-------------------+-----------+------------------+----------------+
# |       time_rounded|price_level|     total_bid_qty|total_bid_trades|
# +-------------------+-----------+------------------+----------------+
# |2020-01-01 01:00:00|     7173.0|17.825999999999997|              16|
# |2020-01-01 01:00:00|     7174.0|15.869000000000002|              30|
# |2020-01-01 01:00:00|     7175.0| 29.78100000000001|              39|
# |2020-01-01 01:00:00|     7176.0| 51.82800000000002|              64|
# |2020-01-01 01:00:00|     7177.0| 52.13700000000002|              60|
# |2020-01-01 01:00:00|     7178.0|105.05199999999999|             100|
# |2020-01-01 01:00:00|     7179.0| 71.12200000000001|              67|
# |2020-01-01 01:00:00|     7180.0| 46.92099999999999|              54|
# |2020-01-01 01:00:00|     7181.0| 38.78600000000001|              38|
# |2020-01-01 01:00:00|     7182.0|            57.685|              54|
# |2020-01-01 01:00:00|     7183.0|35.980000000000004|              29|
# |2020-01-01 01:00:00|     7184.0| 27.68199999999999|              27|
# |2020-01-01 01:00:00|     7185.0|            36.804|              35|
# |2020-01-01 01:00:00|     7186.0|11.467999999999998|              18|
# |2020-01-01 01:00:00|     7187.0|            12.878|              17|
# |2020-01-01 01:00:00|     7188.0|             6.385|               9|
# |2020-01-01 01:00:00|     7189.0|16.823999999999998|               8|
# |2020-01-01 01:00:00|     7190.0|            18.558|               6|
# |2020-01-01 01:15:00|     7171.0|52.401999999999994|              29|
# |2020-01-01 01:15:00|     7172.0|55.815999999999995|              55|
# +-------------------+-----------+------------------+----------------+
# only showing top 20 rows

# %% [markdown]
# ##  STRUCTURE PREPROCESSING

# %%
df_bid_footprint_sorted = transform_and_aggregate_footprint(df_bid_agg_sorted, "bid")
df_bid_footprint_sorted.show()
# Out:
# [Stage 39:>                                                         (0 + 2) / 2]
# +-------------------+--------------------+
# |       time_rounded| aggregated_foot_bid|
# +-------------------+--------------------+
# |2020-01-01 01:00:00|[{7173.0 -> {17.8...|
# |2020-01-01 01:15:00|[{7171.0 -> {52.4...|
# |2020-01-01 01:30:00|[{7171.0 -> {14.8...|
# |2020-01-01 01:45:00|[{7170.0 -> {5.51...|
# |2020-01-01 02:00:00|[{7171.0 -> {3.05...|
# |2020-01-01 02:15:00|[{7184.0 -> {8.39...|
# |2020-01-01 02:30:00|[{7201.0 -> {0.79...|
# |2020-01-01 02:45:00|[{7200.0 -> {34.1...|
# |2020-01-01 03:00:00|[{7206.0 -> {0.03...|
# |2020-01-01 03:15:00|[{7210.0 -> {0.05...|
# |2020-01-01 03:30:00|[{7224.0 -> {17.3...|
# |2020-01-01 03:45:00|[{7228.0 -> {21.4...|
# |2020-01-01 04:00:00|[{7218.0 -> {9.41...|
# |2020-01-01 04:15:00|[{7223.0 -> {0.09...|
# |2020-01-01 04:30:00|[{7215.0 -> {8.56...|
# |2020-01-01 04:45:00|[{7215.0 -> {11.6...|
# |2020-01-01 05:00:00|[{7213.0 -> {5.78...|
# |2020-01-01 05:15:00|[{7211.0 -> {10.2...|
# |2020-01-01 05:30:00|[{7217.0 -> {2.70...|
# |2020-01-01 05:45:00|[{7214.0 -> {3.51...|
# +-------------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession, functions as F
from pyspark.sql.types import StructType, StructField, DoubleType, IntegerType, MapType, StringType
from pyspark.sql.functions import udf, collect_list
import logging

# Initialize logger
logger = logging.getLogger("BidAskDataProcessing")
logging.basicConfig(level=logging.INFO)

# Define the schema for bid and ask data
json_schema_bid = StructType([
    StructField("price_level", DoubleType(), True),
    StructField("bid_qty", DoubleType(), True),
    StructField("bid_trades", IntegerType(), True),
    StructField("bid_trades_aggr", IntegerType(), True)
])

json_schema_ask = StructType([
    StructField("price_level", DoubleType(), True),
    StructField("ask_qty", DoubleType(), True),
    StructField("ask_trades", IntegerType(), True),
    StructField("ask_trades_aggr", IntegerType(), True)
])

def process_foot_data(renko_df, column_name, json_schema, prefix):
    # Convert the array to a single JSON string
    df_with_foot = renko_df.withColumn(f"{column_name}_str", F.concat_ws("", F.col(column_name)))
    
    df_with_foot = df_with_foot.withColumn(f"{column_name}_str", F.regexp_replace(f"{column_name}_str", r'\}\s*\{', '},{'))
    
    # Convert the concatenated string to an array of JSON strings
    df_with_foot = df_with_foot.withColumn(f"{column_name}_json_array", F.split(f"{column_name}_str", r',\{'))
    df_with_foot = df_with_foot.withColumn(f"{column_name}_json_array", F.expr(f"TRANSFORM({column_name}_json_array, x -> concat('{{', x))"))
    
    df_with_foot = df_with_foot.withColumn(f"{column_name}_json", F.explode(f"{column_name}_json_array"))
    
    # Replace any occurrences of "{{" with "{" and "}}" with "}"
    df_with_foot = df_with_foot.withColumn(f"{column_name}_json", F.regexp_replace(F.col(f"{column_name}_json"), r'\{\{', '{'))
    df_with_foot = df_with_foot.withColumn(f"{column_name}_json", F.regexp_replace(F.col(f"{column_name}_json"), r'\}\}', '}'))
    
    # Parse JSON and select the necessary fields
    df = df_with_foot.select(
        F.col("time_rounded"),
        F.from_json(F.col(f"{column_name}_json"), json_schema).alias("data")
    ).select(
        "time_rounded",
        F.round(F.col("data.price_level")).alias("price_level"),
        F.col(f"data.{column_name.split('_')[1]}_qty").alias("qty"),
        F.col(f"data.{column_name.split('_')[1]}_trades").alias("trades"),
        F.col(f"data.{column_name.split('_')[1]}_trades_aggr").alias("trades_aggr")
    ).filter(
        F.col("price_level").isNotNull() &
        F.col("qty").isNotNull() &
        F.col("trades").isNotNull() &
        F.col("trades_aggr").isNotNull()
    )
    
    # Aggregate data
    df_agg = df.groupBy("time_rounded", "price_level").agg(
        F.sum("qty").alias(f"total_{prefix}_qty"),
        F.sum("trades").alias(f"total_{prefix}_trades"),
        F.sum("trades_aggr").alias(f"total_{prefix}_trades_aggr"),
    )
    
    # Sort the aggregated DataFrame by time_rounded and price_level
    df_agg_sorted = df_agg.orderBy("time_rounded", "price_level")
    
    # Additional aggregation step
    df_total_qty = df_agg_sorted.groupBy("time_rounded").agg(
        F.sum(f"total_{prefix}_qty").alias(f"sum_{prefix}_total_qty")
    )

    return df_agg_sorted, df_total_qty

def transform_and_aggregate_footprint(df_agg, column_prefix):
    try:
        return_schema = MapType(
            StringType(),
            StructType(
                [
                    StructField(f"{column_prefix}_qty", DoubleType(), True),
                    StructField(f"{column_prefix}_trades", DoubleType(), True),
                ]
            ),
        )

        def transform_row(price, qty, trades):
            return {
                str(price): {
                    f"{column_prefix}_qty": qty,
                    f"{column_prefix}_trades": trades,
                }
            }

        transform_row_udf = udf(transform_row, return_schema)

        df_transformed = df_agg.withColumn(
            "transformed_aggregated_foot",
            transform_row_udf(
                "price_level",
                F.col(f"total_{column_prefix}_qty").cast(DoubleType()),
                F.col(f"total_{column_prefix}_trades").cast(DoubleType()),
            ),
        )

        df_footprint = df_transformed.groupBy("time_rounded").agg(
            collect_list("transformed_aggregated_foot").alias(
                f"aggregated_foot_{column_prefix}"
            )
        )

        # Sort the footprint by time_rounded
        df_footprint_sorted = df_footprint.orderBy("time_rounded")

        return df_footprint_sorted
    except Exception as e:
        logger.error(f"Error in transform_and_aggregate_footprint: {e}")
        raise

# Process foot_bid and foot_ask columns
df_bid_agg_sorted, df_bid_total_qty = process_foot_data(renko_df, "foot_bid", json_schema_bid, "bid")
df_ask_agg_sorted, df_ask_total_qty = process_foot_data(renko_df, "foot_ask", json_schema_ask, "ask")

# Transform and aggregate the footprint data
df_bid_footprint_sorted = transform_and_aggregate_footprint(df_bid_agg_sorted, "bid")
df_ask_footprint_sorted = transform_and_aggregate_footprint(df_ask_agg_sorted, "ask")


def join_bid_ask_footprints(df, df_bid_qty, df_ask_qty, df_footprint_bids, df_footprint_asks):
    try:
        # Drop unnecessary columns from df
        df = df.drop("foot_bid", "foot_ask")
        
        # Join the df built before 
        df_joined = df.join(df_bid_qty, on="time_rounded", how="outer")\
                      .join(df_ask_qty, on="time_rounded", how="outer")\
                      .join(df_footprint_bids, on="time_rounded", how="outer")\
                      .join(df_footprint_asks, on="time_rounded", how="outer")\
                      .orderBy("time_rounded")
        return df_joined
    except Exception as e:
        logger.error(f"Error in join_bid_ask_footprints: {e}")
        raise

df_joined_final = join_bid_ask_footprints(renko_df, df_bid_total_qty, df_ask_total_qty, df_bid_footprint_sorted, df_ask_footprint_sorted)

def transform_footprint(row):
    bid_data = row["aggregated_foot_bid"]
    ask_data = row["aggregated_foot_ask"]
    aggregated_data = {}
    # TODO : add error management
    if bid_data:
        for bid_item in bid_data:
            for price, row in bid_item.items():
                if price not in aggregated_data:
                    aggregated_data[price] = {
                        "bid_qty": 0,
                        "bid_trades": 0,
                        "ask_qty": 0,
                        "ask_trades": 0,
                    }
                aggregated_data[price]["bid_qty"] += row["bid_qty"]
                aggregated_data[price]["bid_trades"] += row["bid_trades"]

    if ask_data:
        for ask_item in ask_data:
            for price, row in ask_item.items():
                if price not in aggregated_data:
                    aggregated_data[price] = {
                        "bid_qty": 0,
                        "bid_trades": 0,
                        "ask_qty": 0,
                        "ask_trades": 0,
                    }
                aggregated_data[price]["ask_qty"] += row["ask_qty"]
                aggregated_data[price]["ask_trades"] += row["ask_trades"]

    return aggregated_data

df_joined_final = df_joined_final.withColumn(
    "footprint",
    F.udf(lambda row: transform_footprint(row))(
        F.struct([df_joined_final[x] for x in df_joined_final.columns])
    ),
)

# %%
def join_bid_ask_footprints(df, df_bid_qty, df_ask_qty, df_footprint_bids, df_footprint_asks):
    try:
        # Drop unnecessary columns from df
        df = df.drop("foot_bid", "foot_ask")
        
        # Join the df built before 
        df_joined = df.join(df_bid_qty, on="time_rounded", how="outer")\
                      .join(df_ask_qty, on="time_rounded", how="outer")\
                      .join(df_footprint_bids, on="time_rounded", how="outer")\
                      .join(df_footprint_asks, on="time_rounded", how="outer")\
                      .orderBy("time_rounded")
        return df_joined
    except Exception as e:
        logger.error(f"Error in join_bid_ask_footprints: {e}")
        raise
    
df_joined_final = join_bid_ask_footprints(renko_df, df_bid_total_qty, df_ask_total_qty, df_bid_footprint_sorted, df_ask_footprint_sorted)
#df_joined_final.show(100, truncate=False)

# %%
def transform_footprint(row):
    bid_data = row["aggregated_foot_bid"]
    ask_data = row["aggregated_foot_ask"]
    aggregated_data = {}
    # TODO : add error management
    if bid_data:
        for bid_item in bid_data:
            for price, row in bid_item.items():
                if price not in aggregated_data:
                    aggregated_data[price] = {
                        "bid_qty": 0,
                        "bid_trades": 0,
                        "ask_qty": 0,
                        "ask_trades": 0,
                    }
                aggregated_data[price]["bid_qty"] += row["bid_qty"]
                aggregated_data[price]["bid_trades"] += row["bid_trades"]

    if ask_data:
        for ask_item in ask_data:
            for price, row in ask_item.items():
                if price not in aggregated_data:
                    aggregated_data[price] = {
                        "bid_qty": 0,
                        "bid_trades": 0,
                        "ask_qty": 0,
                        "ask_trades": 0,
                    }
                aggregated_data[price]["ask_qty"] += row["ask_qty"]
                aggregated_data[price]["ask_trades"] += row["ask_trades"]

    return aggregated_data

df_joined_final = df_joined_final.withColumn(
    "footprint",
    F.udf(lambda row: transform_footprint(row))(
        F.struct([df_joined_final[x] for x in df_joined_final.columns])
    ),
)

# %%
df_joined_final.printSchema()
# Out:
# root
#  |-- time_rounded: timestamp (nullable = true)
#  |-- open: double (nullable = true)
#  |-- close: double (nullable = true)
#  |-- high: double (nullable = true)
#  |-- low: double (nullable = true)
#  |-- qty: double (nullable = true)
#  |-- sum_bid_total_qty: double (nullable = true)
#  |-- sum_ask_total_qty: double (nullable = true)
#  |-- aggregated_foot_bid: array (nullable = true)
#  |    |-- element: map (containsNull = false)
#  |    |    |-- key: string
#  |    |    |-- value: struct (valueContainsNull = true)
#  |    |    |    |-- bid_qty: double (nullable = true)
#  |    |    |    |-- bid_trades: double (nullable = true)
#  |-- aggregated_foot_ask: array (nullable = true)
#  |    |-- element: map (containsNull = false)
#  |    |    |-- key: string
#  |    |    |-- value: struct (valueContainsNull = true)
#  |    |    |    |-- ask_qty: double (nullable = true)
#  |    |    |    |-- ask_trades: double (nullable = true)
#  |-- footprint: string (nullable = true)

# %%
df_joined_final.select("footprint").show(20, truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |footprint                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{7183.0={ask_trades=14.0, bid_qty=35.980000000000004, ask_qty=14.982000000000001, bid_trades=29.0}, 7182.0={ask_trades=46.0, bid_qty=57.685, ask_qty=39.12800000000001, bid_trades=54.0}, 7181.0={ask_trades=29.0, bid_qty=38.78600000000001, ask_qty=21.082, bid_trades=38.0}, 7191.0={ask_trades=2.0, bid_qty=0, ask_qty=0.9229999999999999, bid_trades=0}, 7180.0={ask_trades=61.0, bid_qty=46.92099999999999, ask_qty=41.25200000000001, bid_trades=54.0}, 7190.0={ask_trades=5.0, bid_qty=18.558, ask_qty=1.5230000000000001, bid_trades=6.0}, 7179.0={ask_trades=24.0, bid_qty=71.12200000000001, ask_qty=10.072999999999999, bid_trades=67.0}, 7189.0={ask_trades=1.0, bid_qty=16.823999999999998, ask_qty=0.778, bid_trades=8.0}, 7177.0={ask_trades=45.0, bid_qty=52.13700000000002, ask_qty=35.711000000000006, bid_trades=60.0}, 7188.0={ask_trades=6.0, bid_qty=6.385, ask_qty=1.053, bid_trades=9.0}, 7178.0={ask_trades=43.0, bid_qty=105.05199999999999, ask_qty=54.688, bid_trades=100.0}, 7187.0={ask_trades=13.0, bid_qty=12.878, ask_qty=5.598, bid_trades=17.0}, 7175.0={ask_trades=26.0, bid_qty=29.78100000000001, ask_qty=13.447999999999997, bid_trades=39.0}, 7186.0={ask_trades=5.0, bid_qty=11.467999999999998, ask_qty=6.332, bid_trades=18.0}, 7176.0={ask_trades=92.0, bid_qty=51.82800000000002, ask_qty=82.49600000000001, bid_trades=64.0}, 7185.0={ask_trades=23.0, bid_qty=36.804, ask_qty=26.493, bid_trades=35.0}, 7173.0={ask_trades=4.0, bid_qty=17.825999999999997, ask_qty=3.7439999999999998, bid_trades=16.0}, 7184.0={ask_trades=15.0, bid_qty=27.68199999999999, ask_qty=19.941, bid_trades=27.0}, 7174.0={ask_trades=38.0, bid_qty=15.869000000000002, ask_qty=4.505999999999999, bid_trades=30.0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |{7171.0={ask_trades=51.0, bid_qty=52.401999999999994, ask_qty=6.914000000000001, bid_trades=29.0}, 7172.0={ask_trades=34.0, bid_qty=55.815999999999995, ask_qty=15.578000000000001, bid_trades=55.0}, 7179.0={ask_trades=7.0, bid_qty=8.432, ask_qty=3.071, bid_trades=4.0}, 7177.0={ask_trades=39.0, bid_qty=33.869, ask_qty=28.694000000000013, bid_trades=23.0}, 7178.0={ask_trades=37.0, bid_qty=32.762, ask_qty=29.21200000000001, bid_trades=46.0}, 7175.0={ask_trades=43.0, bid_qty=73.12, ask_qty=52.611000000000004, bid_trades=68.0}, 7176.0={ask_trades=34.0, bid_qty=45.898, ask_qty=38.40599999999999, bid_trades=35.0}, 7173.0={ask_trades=53.0, bid_qty=73.57699999999998, ask_qty=59.359000000000016, bid_trades=71.0}, 7174.0={ask_trades=61.0, bid_qty=57.34700000000001, ask_qty=40.765, bid_trades=42.0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |{7171.0={ask_trades=0, bid_qty=14.834, ask_qty=0, bid_trades=10.0}, 7172.0={ask_trades=6.0, bid_qty=18.407, ask_qty=5.843000000000001, bid_trades=14.0}, 7179.0={ask_trades=15.0, bid_qty=16.884, ask_qty=3.7159999999999997, bid_trades=8.0}, 7177.0={ask_trades=12.0, bid_qty=7.438, ask_qty=20.016000000000002, bid_trades=14.0}, 7178.0={ask_trades=36.0, bid_qty=25.095, ask_qty=16.641, bid_trades=14.0}, 7175.0={ask_trades=34.0, bid_qty=51.77100000000004, ask_qty=35.42599999999998, bid_trades=49.0}, 7176.0={ask_trades=52.0, bid_qty=22.125999999999998, ask_qty=33.057, bid_trades=30.0}, 7173.0={ask_trades=14.0, bid_qty=0.428, ask_qty=21.814000000000004, bid_trades=6.0}, 7174.0={ask_trades=14.0, bid_qty=5.727, ask_qty=26.022999999999996, bid_trades=11.0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |{7171.0={ask_trades=11.0, bid_qty=49.675000000000004, ask_qty=11.091, bid_trades=48.0}, 7172.0={ask_trades=28.0, bid_qty=16.349, ask_qty=35.202999999999996, bid_trades=20.0}, 7170.0={ask_trades=0, bid_qty=5.518, ask_qty=0, bid_trades=7.0}, 7179.0={ask_trades=9.0, bid_qty=0, ask_qty=27.133, bid_trades=0}, 7177.0={ask_trades=20.0, bid_qty=25.941999999999997, ask_qty=12.229, bid_trades=20.0}, 7178.0={ask_trades=11.0, bid_qty=7.621, ask_qty=11.431999999999999, bid_trades=8.0}, 7175.0={ask_trades=29.0, bid_qty=34.799, ask_qty=23.475999999999996, bid_trades=27.0}, 7176.0={ask_trades=18.0, bid_qty=13.761000000000001, ask_qty=8.422999999999998, bid_trades=11.0}, 7173.0={ask_trades=26.0, bid_qty=26.876999999999995, ask_qty=41.445, bid_trades=29.0}, 7174.0={ask_trades=12.0, bid_qty=22.790000000000003, ask_qty=4.869, bid_trades=18.0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |{7183.0={ask_trades=15.0, bid_qty=0.357, ask_qty=17.027000000000005, bid_trades=6.0}, 7171.0={ask_trades=12.0, bid_qty=3.0500000000000003, ask_qty=6.819000000000001, bid_trades=8.0}, 7182.0={ask_trades=5.0, bid_qty=3.01, ask_qty=1.0, bid_trades=4.0}, 7172.0={ask_trades=18.0, bid_qty=0.727, ask_qty=16.943, bid_trades=1.0}, 7181.0={ask_trades=3.0, bid_qty=0, ask_qty=3.792, bid_trades=0}, 7180.0={ask_trades=21.0, bid_qty=8.03, ask_qty=36.245000000000005, bid_trades=6.0}, 7179.0={ask_trades=31.0, bid_qty=38.294999999999995, ask_qty=67.859, bid_trades=29.0}, 7189.0={ask_trades=8.0, bid_qty=0, ask_qty=3.927, bid_trades=0}, 7177.0={ask_trades=23.0, bid_qty=13.042, ask_qty=22.317999999999998, bid_trades=14.0}, 7188.0={ask_trades=28.0, bid_qty=21.198999999999998, ask_qty=6.186, bid_trades=34.0}, 7178.0={ask_trades=19.0, bid_qty=35.53699999999999, ask_qty=28.435000000000006, bid_trades=10.0}, 7187.0={ask_trades=13.0, bid_qty=32.16300000000001, ask_qty=5.111999999999999, bid_trades=58.0}, 7175.0={ask_trades=20.0, bid_qty=13.688, ask_qty=15.702999999999998, bid_trades=6.0}, 7186.0={ask_trades=21.0, bid_qty=26.772999999999996, ask_qty=27.714000000000002, bid_trades=24.0}, 7176.0={ask_trades=6.0, bid_qty=5.654999999999999, ask_qty=7.274, bid_trades=7.0}, 7173.0={ask_trades=10.0, bid_qty=0, ask_qty=11.003, bid_trades=0}, 7185.0={ask_trades=27.0, bid_qty=12.42, ask_qty=29.455000000000002, bid_trades=25.0}, 7184.0={ask_trades=17.0, bid_qty=3.8919999999999995, ask_qty=15.495999999999999, bid_trades=14.0}, 7174.0={ask_trades=10.0, bid_qty=0.724, ask_qty=14.518999999999998, bid_trades=2.0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |{7210.0={ask_trades=50.0, bid_qty=7.868999999999999, ask_qty=111.414, bid_trades=13.0}, 7204.0={ask_trades=33.0, bid_qty=12.873999999999999, ask_qty=18.704999999999995, bid_trades=18.0}, 7194.0={ask_trades=11.0, bid_qty=2.201, ask_qty=13.836, bid_trades=3.0}, 7203.0={ask_trades=21.0, bid_qty=22.883, ask_qty=5.459999999999999, bid_trades=22.0}, 7193.0={ask_trades=11.0, bid_qty=6.046, ask_qty=16.105999999999998, bid_trades=3.0}, 7206.0={ask_trades=41.0, bid_qty=14.762, ask_qty=52.06599999999998, bid_trades=36.0}, 7192.0={ask_trades=21.0, bid_qty=7.827999999999998, ask_qty=20.128, bid_trades=16.0}, 7205.0={ask_trades=9.0, bid_qty=9.5, ask_qty=8.756, bid_trades=7.0}, 7191.0={ask_trades=29.0, bid_qty=24.221, ask_qty=47.33299999999999, bid_trades=14.0}, 7208.0={ask_trades=38.0, bid_qty=47.967999999999996, ask_qty=21.577000000000005, bid_trades=42.0}, 7190.0={ask_trades=21.0, bid_qty=6.154999999999999, ask_qty=40.184, bid_trades=10.0}, 7207.0={ask_trades=52.0, bid_qty=42.428000000000004, ask_qty=36.33200000000001, bid_trades=55.0}, 7209.0={ask_trades=71.0, bid_qty=27.965999999999994, ask_qty=58.05899999999999, bid_trades=51.0}, 7199.0={ask_trades=35.0, bid_qty=20.762000000000008, ask_qty=24.787, bid_trades=41.0}, 7198.0={ask_trades=31.0, bid_qty=17.044, ask_qty=24.446999999999996, bid_trades=42.0}, 7197.0={ask_trades=68.0, bid_qty=59.337, ask_qty=43.59900000000002, bid_trades=71.0}, 7196.0={ask_trades=13.0, bid_qty=13.340999999999998, ask_qty=7.437999999999998, bid_trades=26.0}, 7195.0={ask_trades=23.0, bid_qty=26.363, ask_qty=25.019000000000005, bid_trades=20.0}, 7200.0={ask_trades=41.0, bid_qty=0.896, ask_qty=57.09600000000001, bid_trades=7.0}, 7202.0={ask_trades=16.0, bid_qty=9.395, ask_qty=23.815, bid_trades=15.0}, 7201.0={ask_trades=27.0, bid_qty=0, ask_qty=53.602999999999994, bid_trades=0}, 7189.0={ask_trades=42.0, bid_qty=33.982000000000006, ask_qty=47.03, bid_trades=35.0}, 7188.0={ask_trades=29.0, bid_qty=14.998999999999999, ask_qty=39.07000000000001, bid_trades=30.0}, 7187.0={ask_trades=25.0, bid_qty=24.711, ask_qty=22.049, bid_trades=29.0}, 7186.0={ask_trades=34.0, bid_qty=5.964, ask_qty=35.773, bid_trades=18.0}, 7185.0={ask_trades=4.0, bid_qty=6.2, ask_qty=4.26, bid_trades=8.0}, 7184.0={ask_trades=1.0, bid_qty=8.39, ask_qty=0.05, bid_trades=4.0}}                  |
# |{7212.0={ask_trades=50.0, bid_qty=38.302, ask_qty=45.602, bid_trades=46.0}, 7213.0={ask_trades=52.0, bid_qty=47.72300000000001, ask_qty=38.70800000000001, bid_trades=64.0}, 7210.0={ask_trades=59.0, bid_qty=54.217000000000006, ask_qty=62.431000000000004, bid_trades=61.0}, 7211.0={ask_trades=51.0, bid_qty=34.690999999999995, ask_qty=53.238000000000014, bid_trades=48.0}, 7204.0={ask_trades=6.0, bid_qty=21.914000000000005, ask_qty=15.367999999999999, bid_trades=32.0}, 7203.0={ask_trades=10.0, bid_qty=10.537999999999998, ask_qty=14.304, bid_trades=14.0}, 7225.0={ask_trades=6.0, bid_qty=0, ask_qty=18.348000000000003, bid_trades=0}, 7206.0={ask_trades=5.0, bid_qty=18.790000000000003, ask_qty=0.24000000000000002, bid_trades=20.0}, 7205.0={ask_trades=3.0, bid_qty=15.401000000000005, ask_qty=0.28300000000000003, bid_trades=16.0}, 7208.0={ask_trades=73.0, bid_qty=47.35300000000001, ask_qty=84.45800000000003, bid_trades=82.0}, 7207.0={ask_trades=27.0, bid_qty=38.303000000000004, ask_qty=19.152000000000005, bid_trades=49.0}, 7209.0={ask_trades=62.0, bid_qty=58.83399999999999, ask_qty=74.618, bid_trades=68.0}, 7220.0={ask_trades=59.0, bid_qty=41.959999999999994, ask_qty=62.67900000000001, bid_trades=64.0}, 7223.0={ask_trades=24.0, bid_qty=1.707, ask_qty=23.39, bid_trades=2.0}, 7224.0={ask_trades=8.0, bid_qty=0, ask_qty=1.725, bid_trades=0}, 7221.0={ask_trades=92.0, bid_qty=20.63, ask_qty=53.91299999999997, bid_trades=37.0}, 7202.0={ask_trades=7.0, bid_qty=1.75, ask_qty=6.707000000000001, bid_trades=13.0}, 7222.0={ask_trades=88.0, bid_qty=10.719, ask_qty=58.14100000000001, bid_trades=21.0}, 7201.0={ask_trades=0, bid_qty=0.791, ask_qty=0, bid_trades=6.0}, 7216.0={ask_trades=36.0, bid_qty=19.791000000000007, ask_qty=20.527, bid_trades=32.0}, 7217.0={ask_trades=54.0, bid_qty=20.481000000000005, ask_qty=35.062, bid_trades=33.0}, 7214.0={ask_trades=44.0, bid_qty=60.595000000000006, ask_qty=14.204999999999998, bid_trades=62.0}, 7215.0={ask_trades=37.0, bid_qty=42.92300000000001, ask_qty=58.52699999999999, bid_trades=45.0}, 7218.0={ask_trades=32.0, bid_qty=24.38, ask_qty=55.762, bid_trades=50.0}, 7219.0={ask_trades=45.0, bid_qty=16.485000000000003, ask_qty=28.535, bid_trades=39.0}}                                                                                                              |
# |{7200.0={ask_trades=24.0, bid_qty=34.189, ask_qty=8.467, bid_trades=55.0}, 7210.0={ask_trades=24.0, bid_qty=0.646, ask_qty=16.621, bid_trades=1.0}, 7202.0={ask_trades=15.0, bid_qty=14.143, ask_qty=16.416, bid_trades=16.0}, 7211.0={ask_trades=9.0, bid_qty=0, ask_qty=5.625, bid_trades=0}, 7201.0={ask_trades=34.0, bid_qty=22.757000000000005, ask_qty=20.694000000000003, bid_trades=67.0}, 7204.0={ask_trades=42.0, bid_qty=32.425000000000004, ask_qty=25.665999999999997, bid_trades=40.0}, 7203.0={ask_trades=46.0, bid_qty=29.589000000000006, ask_qty=56.227000000000004, bid_trades=31.0}, 7206.0={ask_trades=42.0, bid_qty=24.95700000000001, ask_qty=55.05599999999999, bid_trades=27.0}, 7205.0={ask_trades=46.0, bid_qty=16.666, ask_qty=56.462, bid_trades=27.0}, 7208.0={ask_trades=19.0, bid_qty=2.4829999999999997, ask_qty=13.738, bid_trades=6.0}, 7207.0={ask_trades=20.0, bid_qty=2.593, ask_qty=17.227999999999998, bid_trades=4.0}, 7209.0={ask_trades=24.0, bid_qty=2.7870000000000004, ask_qty=7.935999999999997, bid_trades=12.0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |{7212.0={ask_trades=60.0, bid_qty=39.12199999999999, ask_qty=39.95500000000001, bid_trades=50.0}, 7213.0={ask_trades=40.0, bid_qty=35.806999999999995, ask_qty=59.60199999999998, bid_trades=42.0}, 7210.0={ask_trades=15.0, bid_qty=12.386, ask_qty=4.208999999999999, bid_trades=16.0}, 7211.0={ask_trades=34.0, bid_qty=48.02900000000001, ask_qty=25.551, bid_trades=58.0}, 7216.0={ask_trades=20.0, bid_qty=19.780999999999995, ask_qty=9.547999999999998, bid_trades=15.0}, 7217.0={ask_trades=8.0, bid_qty=10.98, ask_qty=2.338, bid_trades=17.0}, 7214.0={ask_trades=40.0, bid_qty=59.06799999999999, ask_qty=17.069, bid_trades=33.0}, 7206.0={ask_trades=2.0, bid_qty=0.035, ask_qty=5.85, bid_trades=1.0}, 7215.0={ask_trades=30.0, bid_qty=35.919999999999995, ask_qty=30.723999999999993, bid_trades=38.0}, 7208.0={ask_trades=8.0, bid_qty=15.165999999999995, ask_qty=6.125, bid_trades=24.0}, 7207.0={ask_trades=13.0, bid_qty=9.050999999999998, ask_qty=12.837999999999997, bid_trades=17.0}, 7218.0={ask_trades=2.0, bid_qty=0, ask_qty=0.002, bid_trades=0}, 7209.0={ask_trades=14.0, bid_qty=17.840000000000003, ask_qty=13.701, bid_trades=30.0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |{7231.0={ask_trades=10.0, bid_qty=24.681, ask_qty=0.108, bid_trades=24.0}, 7230.0={ask_trades=30.0, bid_qty=8.246, ask_qty=42.276999999999994, bid_trades=14.0}, 7212.0={ask_trades=14.0, bid_qty=0.04, ask_qty=4.891, bid_trades=1.0}, 7213.0={ask_trades=6.0, bid_qty=0.012, ask_qty=5.0, bid_trades=2.0}, 7233.0={ask_trades=14.0, bid_qty=2.1390000000000002, ask_qty=6.9860000000000015, bid_trades=5.0}, 7210.0={ask_trades=5.0, bid_qty=0.05, ask_qty=2.912, bid_trades=1.0}, 7232.0={ask_trades=51.0, bid_qty=6.6080000000000005, ask_qty=20.420000000000005, bid_trades=19.0}, 7211.0={ask_trades=13.0, bid_qty=5.556, ask_qty=3.748, bid_trades=4.0}, 7227.0={ask_trades=30.0, bid_qty=13.172999999999996, ask_qty=40.231000000000016, bid_trades=12.0}, 7228.0={ask_trades=22.0, bid_qty=13.547999999999998, ask_qty=40.629999999999995, bid_trades=18.0}, 7225.0={ask_trades=24.0, bid_qty=5.436000000000001, ask_qty=30.120999999999995, bid_trades=15.0}, 7226.0={ask_trades=27.0, bid_qty=12.504999999999999, ask_qty=10.538999999999998, bid_trades=27.0}, 7208.0={ask_trades=7.0, bid_qty=0, ask_qty=14.757000000000001, bid_trades=0}, 7207.0={ask_trades=4.0, bid_qty=0, ask_qty=2.76, bid_trades=0}, 7229.0={ask_trades=26.0, bid_qty=37.809000000000005, ask_qty=11.161999999999997, bid_trades=21.0}, 7209.0={ask_trades=3.0, bid_qty=0, ask_qty=0.864, bid_trades=0}, 7220.0={ask_trades=33.0, bid_qty=11.954999999999998, ask_qty=63.11100000000001, bid_trades=27.0}, 7223.0={ask_trades=58.0, bid_qty=78.469, ask_qty=53.81100000000001, bid_trades=70.0}, 7224.0={ask_trades=44.0, bid_qty=10.965999999999998, ask_qty=37.57599999999999, bid_trades=10.0}, 7221.0={ask_trades=27.0, bid_qty=21.156, ask_qty=35.479, bid_trades=32.0}, 7222.0={ask_trades=63.0, bid_qty=27.29800000000001, ask_qty=57.24399999999999, bid_trades=36.0}, 7216.0={ask_trades=12.0, bid_qty=12.157, ask_qty=8.171, bid_trades=8.0}, 7217.0={ask_trades=33.0, bid_qty=35.505999999999986, ask_qty=22.686, bid_trades=29.0}, 7214.0={ask_trades=7.0, bid_qty=7.652999999999999, ask_qty=5.302, bid_trades=14.0}, 7215.0={ask_trades=35.0, bid_qty=4.136, ask_qty=41.46100000000001, bid_trades=16.0}, 7218.0={ask_trades=44.0, bid_qty=29.418000000000013, ask_qty=40.397999999999996, bid_trades=43.0}, 7219.0={ask_trades=24.0, bid_qty=3.677, ask_qty=32.519999999999996, bid_trades=14.0}}|
# |{7227.0={ask_trades=101.0, bid_qty=90.514, ask_qty=99.17700000000002, bid_trades=100.0}, 7228.0={ask_trades=65.0, bid_qty=57.396999999999984, ask_qty=73.49000000000002, bid_trades=53.0}, 7225.0={ask_trades=54.0, bid_qty=61.75199999999997, ask_qty=82.28399999999999, bid_trades=71.0}, 7226.0={ask_trades=55.0, bid_qty=88.65599999999998, ask_qty=85.20900000000005, bid_trades=93.0}, 7229.0={ask_trades=25.0, bid_qty=22.877, ask_qty=15.335000000000003, bid_trades=19.0}, 7231.0={ask_trades=8.0, bid_qty=3.668, ask_qty=2.8890000000000002, bid_trades=5.0}, 7230.0={ask_trades=20.0, bid_qty=14.302, ask_qty=12.363999999999999, bid_trades=16.0}, 7223.0={ask_trades=2.0, bid_qty=0, ask_qty=3.6439999999999997, bid_trades=0}, 7224.0={ask_trades=17.0, bid_qty=17.315, ask_qty=25.272000000000002, bid_trades=20.0}, 7222.0={ask_trades=4.0, bid_qty=0, ask_qty=12.396999999999998, bid_trades=0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |{7231.0={ask_trades=49.0, bid_qty=36.757, ask_qty=16.567, bid_trades=33.0}, 7230.0={ask_trades=45.0, bid_qty=62.681999999999995, ask_qty=46.504999999999995, bid_trades=27.0}, 7235.0={ask_trades=77.0, bid_qty=99.03099999999999, ask_qty=102.513, bid_trades=73.0}, 7234.0={ask_trades=69.0, bid_qty=42.11399999999999, ask_qty=52.592999999999996, bid_trades=59.0}, 7233.0={ask_trades=29.0, bid_qty=19.175, ask_qty=26.253000000000007, bid_trades=18.0}, 7232.0={ask_trades=18.0, bid_qty=10.581999999999997, ask_qty=6.580999999999999, bid_trades=10.0}, 7239.0={ask_trades=21.0, bid_qty=0.825, ask_qty=18.481, bid_trades=2.0}, 7238.0={ask_trades=36.0, bid_qty=11.517000000000001, ask_qty=28.768000000000015, bid_trades=19.0}, 7228.0={ask_trades=22.0, bid_qty=21.433, ask_qty=20.791999999999998, bid_trades=35.0}, 7237.0={ask_trades=45.0, bid_qty=41.484, ask_qty=38.51199999999999, bid_trades=47.0}, 7236.0={ask_trades=93.0, bid_qty=51.091, ask_qty=96.403, bid_trades=56.0}, 7229.0={ask_trades=18.0, bid_qty=25.669, ask_qty=45.43900000000001, bid_trades=31.0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |{7231.0={ask_trades=9.0, bid_qty=0.936, ask_qty=3.7910000000000004, bid_trades=7.0}, 7230.0={ask_trades=11.0, bid_qty=7.992999999999999, ask_qty=4.45, bid_trades=15.0}, 7220.0={ask_trades=31.0, bid_qty=33.66700000000001, ask_qty=31.868000000000002, bid_trades=54.0}, 7240.0={ask_trades=3.0, bid_qty=0, ask_qty=0.248, bid_trades=0}, 7235.0={ask_trades=0, bid_qty=52.175, ask_qty=0, bid_trades=23.0}, 7223.0={ask_trades=51.0, bid_qty=23.496000000000006, ask_qty=26.341, bid_trades=37.0}, 7234.0={ask_trades=0, bid_qty=0.14300000000000002, ask_qty=0, bid_trades=3.0}, 7224.0={ask_trades=36.0, bid_qty=10.584999999999999, ask_qty=36.833000000000006, bid_trades=21.0}, 7233.0={ask_trades=0, bid_qty=4.633, ask_qty=0, bid_trades=5.0}, 7221.0={ask_trades=32.0, bid_qty=32.626000000000005, ask_qty=26.828000000000003, bid_trades=34.0}, 7232.0={ask_trades=0, bid_qty=0.21100000000000002, ask_qty=0, bid_trades=2.0}, 7222.0={ask_trades=53.0, bid_qty=65.021, ask_qty=31.201999999999998, bid_trades=42.0}, 7239.0={ask_trades=29.0, bid_qty=28.448, ask_qty=21.32200000000001, bid_trades=12.0}, 7227.0={ask_trades=30.0, bid_qty=12.919999999999996, ask_qty=30.570000000000004, bid_trades=12.0}, 7238.0={ask_trades=37.0, bid_qty=26.242000000000004, ask_qty=25.011, bid_trades=32.0}, 7228.0={ask_trades=12.0, bid_qty=33.431000000000004, ask_qty=21.058, bid_trades=38.0}, 7237.0={ask_trades=4.0, bid_qty=21.265, ask_qty=0.8870000000000001, bid_trades=26.0}, 7225.0={ask_trades=14.0, bid_qty=19.327000000000012, ask_qty=5.82, bid_trades=30.0}, 7236.0={ask_trades=1.0, bid_qty=17.256, ask_qty=0.3, bid_trades=9.0}, 7226.0={ask_trades=36.0, bid_qty=24.58600000000001, ask_qty=45.491, bid_trades=69.0}, 7229.0={ask_trades=9.0, bid_qty=23.255999999999997, ask_qty=9.394, bid_trades=36.0}, 7218.0={ask_trades=9.0, bid_qty=9.415, ask_qty=6.502000000000001, bid_trades=12.0}, 7219.0={ask_trades=10.0, bid_qty=25.926000000000002, ask_qty=14.141000000000002, bid_trades=34.0}}                                                                                                                                                                                                                                                                                                                                                                         |
# |{7231.0={ask_trades=43.0, bid_qty=54.91099999999999, ask_qty=21.816000000000006, bid_trades=78.0}, 7230.0={ask_trades=86.0, bid_qty=63.614999999999974, ask_qty=66.13400000000001, bid_trades=45.0}, 7223.0={ask_trades=10.0, bid_qty=0.092, ask_qty=3.138, bid_trades=2.0}, 7234.0={ask_trades=8.0, bid_qty=0, ask_qty=3.2709999999999995, bid_trades=0}, 7224.0={ask_trades=25.0, bid_qty=15.037, ask_qty=13.78500000000001, bid_trades=4.0}, 7233.0={ask_trades=25.0, bid_qty=4.051, ask_qty=6.713999999999999, bid_trades=3.0}, 7232.0={ask_trades=21.0, bid_qty=0.201, ask_qty=8.048, bid_trades=2.0}, 7227.0={ask_trades=29.0, bid_qty=14.768, ask_qty=13.933000000000002, bid_trades=18.0}, 7228.0={ask_trades=32.0, bid_qty=17.332, ask_qty=34.292, bid_trades=17.0}, 7225.0={ask_trades=13.0, bid_qty=0.346, ask_qty=19.186999999999998, bid_trades=1.0}, 7226.0={ask_trades=12.0, bid_qty=0, ask_qty=9.987, bid_trades=0}, 7229.0={ask_trades=26.0, bid_qty=16.955000000000002, ask_qty=36.492000000000004, bid_trades=24.0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |{7231.0={ask_trades=4.0, bid_qty=21.062, ask_qty=1.568, bid_trades=15.0}, 7230.0={ask_trades=0, bid_qty=6.254999999999998, ask_qty=0, bid_trades=21.0}, 7235.0={ask_trades=31.0, bid_qty=20.341, ask_qty=24.013999999999992, bid_trades=21.0}, 7234.0={ask_trades=30.0, bid_qty=12.284, ask_qty=10.317999999999998, bid_trades=25.0}, 7233.0={ask_trades=10.0, bid_qty=14.444, ask_qty=2.488, bid_trades=22.0}, 7232.0={ask_trades=3.0, bid_qty=14.017, ask_qty=1.02, bid_trades=19.0}, 7227.0={ask_trades=22.0, bid_qty=26.28300000000001, ask_qty=16.453, bid_trades=32.0}, 7228.0={ask_trades=5.0, bid_qty=3.0800000000000005, ask_qty=2.904, bid_trades=9.0}, 7225.0={ask_trades=20.0, bid_qty=28.436, ask_qty=17.45, bid_trades=40.0}, 7226.0={ask_trades=17.0, bid_qty=28.305000000000003, ask_qty=20.029999999999998, bid_trades=21.0}, 7229.0={ask_trades=3.0, bid_qty=2.064, ask_qty=0.8729999999999999, bid_trades=5.0}, 7220.0={ask_trades=45.0, bid_qty=28.230999999999998, ask_qty=16.987000000000005, bid_trades=26.0}, 7223.0={ask_trades=15.0, bid_qty=8.014, ask_qty=31.827000000000005, bid_trades=23.0}, 7224.0={ask_trades=16.0, bid_qty=12.886999999999999, ask_qty=24.655, bid_trades=19.0}, 7221.0={ask_trades=6.0, bid_qty=18.552, ask_qty=13.301, bid_trades=20.0}, 7222.0={ask_trades=24.0, bid_qty=28.831, ask_qty=40.836999999999996, bid_trades=54.0}, 7216.0={ask_trades=0, bid_qty=2.381, ask_qty=0, bid_trades=7.0}, 7238.0={ask_trades=30.0, bid_qty=9.103, ask_qty=25.746, bid_trades=28.0}, 7217.0={ask_trades=11.0, bid_qty=15.938, ask_qty=0.011000000000000003, bid_trades=15.0}, 7237.0={ask_trades=32.0, bid_qty=32.897, ask_qty=23.433999999999997, bid_trades=30.0}, 7236.0={ask_trades=35.0, bid_qty=52.153000000000006, ask_qty=27.086, bid_trades=47.0}, 7215.0={ask_trades=3.0, bid_qty=8.562999999999999, ask_qty=0.603, bid_trades=9.0}, 7218.0={ask_trades=0, bid_qty=14.221999999999998, ask_qty=0, bid_trades=14.0}, 7219.0={ask_trades=1.0, bid_qty=12.243999999999998, ask_qty=0.003, bid_trades=10.0}}                                                                                                                                                                                                                                                                                                                                        |
# |{7220.0={ask_trades=45.0, bid_qty=15.750999999999994, ask_qty=81.70000000000002, bid_trades=30.0}, 7223.0={ask_trades=17.0, bid_qty=9.465, ask_qty=10.943, bid_trades=7.0}, 7224.0={ask_trades=8.0, bid_qty=30.665000000000003, ask_qty=4.181, bid_trades=13.0}, 7221.0={ask_trades=95.0, bid_qty=63.68099999999998, ask_qty=89.22900000000001, bid_trades=74.0}, 7222.0={ask_trades=41.0, bid_qty=15.379, ask_qty=71.75799999999998, bid_trades=17.0}, 7216.0={ask_trades=6.0, bid_qty=0.45, ask_qty=10.355, bid_trades=3.0}, 7217.0={ask_trades=14.0, bid_qty=0.065, ask_qty=8.605, bid_trades=2.0}, 7225.0={ask_trades=56.0, bid_qty=14.181000000000001, ask_qty=21.560000000000002, bid_trades=9.0}, 7226.0={ask_trades=9.0, bid_qty=6.372, ask_qty=8.466, bid_trades=4.0}, 7215.0={ask_trades=4.0, bid_qty=11.641, ask_qty=4.074, bid_trades=3.0}, 7218.0={ask_trades=15.0, bid_qty=0.614, ask_qty=26.869, bid_trades=5.0}, 7219.0={ask_trades=25.0, bid_qty=18.525000000000002, ask_qty=26.863000000000003, bid_trades=16.0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |{7220.0={ask_trades=10.0, bid_qty=13.392999999999999, ask_qty=4.718000000000001, bid_trades=23.0}, 7223.0={ask_trades=31.0, bid_qty=35.992, ask_qty=37.33599999999999, bid_trades=27.0}, 7224.0={ask_trades=29.0, bid_qty=9.94, ask_qty=21.031, bid_trades=21.0}, 7213.0={ask_trades=0, bid_qty=5.785999999999999, ask_qty=0, bid_trades=11.0}, 7221.0={ask_trades=8.0, bid_qty=6.610999999999998, ask_qty=7.961999999999999, bid_trades=15.0}, 7222.0={ask_trades=22.0, bid_qty=20.578999999999997, ask_qty=28.205000000000005, bid_trades=21.0}, 7216.0={ask_trades=14.0, bid_qty=6.632, ask_qty=9.966000000000001, bid_trades=16.0}, 7217.0={ask_trades=1.0, bid_qty=1.257, ask_qty=0.035, bid_trades=10.0}, 7225.0={ask_trades=21.0, bid_qty=0.35700000000000004, ask_qty=9.875000000000004, bid_trades=6.0}, 7214.0={ask_trades=11.0, bid_qty=1.9189999999999996, ask_qty=6.771, bid_trades=17.0}, 7215.0={ask_trades=29.0, bid_qty=10.507000000000001, ask_qty=27.771000000000008, bid_trades=23.0}, 7218.0={ask_trades=1.0, bid_qty=11.418, ask_qty=0.01, bid_trades=5.0}, 7219.0={ask_trades=0, bid_qty=24.597000000000005, ask_qty=0, bid_trades=16.0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |{7216.0={ask_trades=30.0, bid_qty=17.174000000000003, ask_qty=33.39, bid_trades=14.0}, 7217.0={ask_trades=37.0, bid_qty=27.287, ask_qty=20.441, bid_trades=18.0}, 7214.0={ask_trades=34.0, bid_qty=31.092, ask_qty=44.07899999999999, bid_trades=24.0}, 7215.0={ask_trades=77.0, bid_qty=35.368000000000016, ask_qty=51.62899999999999, bid_trades=49.0}, 7218.0={ask_trades=32.0, bid_qty=25.387, ask_qty=15.321000000000007, bid_trades=25.0}, 7212.0={ask_trades=17.0, bid_qty=32.707, ask_qty=16.738, bid_trades=31.0}, 7213.0={ask_trades=9.0, bid_qty=12.435999999999996, ask_qty=25.419999999999998, bid_trades=26.0}, 7211.0={ask_trades=5.0, bid_qty=10.267999999999995, ask_qty=2.387, bid_trades=9.0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |{7217.0={ask_trades=12.0, bid_qty=2.706, ask_qty=9.247, bid_trades=7.0}, 7225.0={ask_trades=8.0, bid_qty=0.099, ask_qty=6.622000000000001, bid_trades=1.0}, 7218.0={ask_trades=9.0, bid_qty=2.612, ask_qty=4.961, bid_trades=12.0}, 7219.0={ask_trades=14.0, bid_qty=6.6259999999999994, ask_qty=5.956999999999999, bid_trades=13.0}, 7220.0={ask_trades=12.0, bid_qty=6.126, ask_qty=1.7349999999999997, bid_trades=11.0}, 7223.0={ask_trades=22.0, bid_qty=35.587999999999994, ask_qty=10.194, bid_trades=23.0}, 7224.0={ask_trades=27.0, bid_qty=28.387000000000004, ask_qty=12.681999999999997, bid_trades=23.0}, 7221.0={ask_trades=31.0, bid_qty=38.343, ask_qty=25.205999999999996, bid_trades=32.0}, 7222.0={ask_trades=19.0, bid_qty=12.328, ask_qty=30.000999999999998, bid_trades=12.0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |{7216.0={ask_trades=5.0, bid_qty=7.664, ask_qty=0.457, bid_trades=14.0}, 7217.0={ask_trades=7.0, bid_qty=18.686, ask_qty=0.44799999999999995, bid_trades=25.0}, 7214.0={ask_trades=24.0, bid_qty=3.5109999999999992, ask_qty=13.85, bid_trades=30.0}, 7215.0={ask_trades=19.0, bid_qty=13.106, ask_qty=14.824000000000002, bid_trades=27.0}, 7218.0={ask_trades=19.0, bid_qty=9.831999999999997, ask_qty=51.51200000000001, bid_trades=21.0}, 7219.0={ask_trades=18.0, bid_qty=8.767, ask_qty=12.398, bid_trades=9.0}, 7220.0={ask_trades=12.0, bid_qty=12.562000000000001, ask_qty=4.694000000000001, bid_trades=5.0}, 7223.0={ask_trades=9.0, bid_qty=18.021, ask_qty=5.643000000000001, bid_trades=16.0}, 7224.0={ask_trades=2.0, bid_qty=5.586, ask_qty=0.057, bid_trades=3.0}, 7221.0={ask_trades=8.0, bid_qty=11.535, ask_qty=11.924, bid_trades=8.0}, 7222.0={ask_trades=7.0, bid_qty=7.01, ask_qty=1.367, bid_trades=2.0}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
df_joined_final.select("aggregated_foot_ask").show(20, truncate=False)
df_joined_final.select("aggregated_foot_bid").show(20, truncate=False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |aggregated_foot_ask                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[{7173.0 -> {3.7439999999999998, 4.0}}, {7174.0 -> {4.505999999999999, 38.0}}, {7175.0 -> {13.447999999999997, 26.0}}, {7176.0 -> {82.49600000000001, 92.0}}, {7177.0 -> {35.711000000000006, 45.0}}, {7178.0 -> {54.688, 43.0}}, {7179.0 -> {10.072999999999999, 24.0}}, {7180.0 -> {41.25200000000001, 61.0}}, {7181.0 -> {21.082, 29.0}}, {7182.0 -> {
0}}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# |[{7213.0 -> {5.785999999999999, 11.0}}, {7214.0 -> {1.9189999999999996, 17.0}}, {7215.0 -> {10.507000000000001, 23.0}}, {7216.0 -> {6.632, 16.0}}, {7217.0 -> {1.257, 10.0}}, {7218.0 -> {11.418, 5.0}}, {7219.0 -> {24.597000000000005, 16.0}}, {7220.0 -> {13.392999999999999, 23.0}}, {7221.0 -> {6.610999999999998, 15.0}}, {7222.0 -> {20.578999999999997, 21.0}}, {7223.0 -> {35.992, 27.0}}, {7224.0 -> {9.94, 21.0}}, {7225.0 -> {0.35700000000000004, 6.0}}]                                                                                                                                                                                                                                                                                                                                                                                                 |
# |[{7211.0 -> {10.267999999999995, 9.0}}, {7212.0 -> {32.707, 31.0}}, {7213.0 -> {12.435999999999996, 26.0}}, {7214.0 -> {31.092, 24.0}}, {7215.0 -> {35.368000000000016, 49.0}}, {7216.0 -> {17.174000000000003, 14.0}}, {7217.0 -> {27.287, 18.0}}, {7218.0 -> {25.387, 25.0}}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |[{7217.0 -> {2.706, 7.0}}, {7218.0 -> {2.612, 12.0}}, {7219.0 -> {6.6259999999999994, 13.0}}, {7220.0 -> {6.126, 11.0}}, {7221.0 -> {38.343, 32.0}}, {7222.0 -> {12.328, 12.0}}, {7223.0 -> {35.587999999999994, 23.0}}, {7224.0 -> {28.387000000000004, 23.0}}, {7225.0 -> {0.099, 1.0}}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |[{7214.0 -> {3.5109999999999992, 30.0}}, {7215.0 -> {13.106, 27.0}}, {7216.0 -> {7.664, 14.0}}, {7217.0 -> {18.686, 25.0}}, {7218.0 -> {9.831999999999997, 21.0}}, {7219.0 -> {8.767, 9.0}}, {7220.0 -> {12.562000000000001, 5.0}}, {7221.0 -> {11.535, 8.0}}, {7222.0 -> {7.01, 2.0}}, {7223.0 -> {18.021, 16.0}}, {7224.0 -> {5.586, 3.0}}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# # DATA VALIDATION

# %% [markdown]
# # BREAK

# %%
def transform_and_aggregate_footprint(df_agg, column_prefix):
    """
    Transforms and aggregates the footprint data for bids or asks.
    
    :param df_agg: DataFrame to transform and aggregate.
    :param column_prefix: Prefix indicating whether it's for bids or asks ('bid' or 'ask').
    :return: Transformed and aggregated DataFrame.
    """
    # Define the return schema based on prefix
    return_schema = MapType(
        StringType(), 
        StructType([
            StructField(f"{column_prefix}_qty", DoubleType(), True),
            StructField(f"{column_prefix}_trades", DoubleType(), True)
        ])
    )

    # Define the transformation UDF
    def transform_row(price, qty, trades):
        return {str(price): {f"{column_prefix}_qty": qty, f"{column_prefix}_trades": trades}}

    transform_row_udf = udf(transform_row, return_schema)

    # Apply the transformation UDF and aggregate
    df_transformed = df_agg.withColumn("transformed_aggregated_foot", 
                                    transform_row_udf("price_level", f"total_{column_prefix}_qty", f"total_{column_prefix}_trades"))

    df_footprint = df_transformed.groupBy("time_rounded").agg(
        collect_list("transformed_aggregated_foot").alias(f"aggregated_foot_{column_prefix}")
    ).sort("time_rounded")

    return df_footprint

# %%
path = '/root/Cicada-binance/cores/aggTrades/historical/transformation/src/VolumeProfileCluster/data/test.parquet'
df = spark_conf.read.parquet(path)

# %%
df.show(20)
# Out:
# +------------+-----------+-------------+----------------+---------------------+
# |time_rounded|price_level|total_bid_qty|total_bid_trades|total_bid_trades_aggr|
# +------------+-----------+-------------+----------------+---------------------+
# +------------+-----------+-------------+----------------+---------------------+
